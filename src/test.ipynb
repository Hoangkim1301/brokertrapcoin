# %%
import requests
from bs4 import BeautifulSoup

def scrape_yahoo_finance_news(stock_symbol):
    # Replace 'AAPL' with the desired stock symbol
    url = f'https://finance.yahoo.com/quote/{stock_symbol}/news?p={stock_symbol}'

    # Send an HTTP request to the URL
    response = requests.get(url)

    # Check if the request was successful (status code 200)
    if response.status_code == 200:
        # Parse the HTML content of the page
        soup = BeautifulSoup(response.text, 'html.parser')

        # Find HTML elements containing news headlines (modify as per the website's structure)
        headline_elements = soup.find_all('h3', class_='Mb(5px)')

        # Extract and print news headlines
        for headline_element in headline_elements:
            print(headline_element.text.strip())
    else:
        print(f"Failed to retrieve the page. Status code: {response.status_code}")

if __name__ == "__main__":
    stock_symbol = 'appl'  # Replace with the desired stock symbol
    scrape_yahoo_finance_news(stock_symbol)
# Out:
# Failed to retrieve the page. Status code: 404

# %%
from bs4 import BeautifulSoup as btfs
import requests, re

url = 'https://finance.yahoo.com/news/'
url_stock_market_news = 'https://finance.yahoo.com/topic/stock-market-news/'
url_aaple = 'https://finance.yahoo.com/quote/AAPL/'
response = requests.get(url_aaple)

if response.status_code == 200:
    #parse the html content of the page
    soup = btfs(response.text, 'html.parser')
    # Find HTML elements containing news headlines (modify as per the website's structure)
    headlines = soup.find_all('h3', class_='My(0) P(0) Wow(bw) Ov(h)')

    print(len(headlines))
    
    for headline in headlines:
        print(headlines)
        print(headline.text.strip())
        headline = str(headline)
        #title = re.findall('\>[0-9a-zA-Z\s\,\."]*', headline)
        #print(headline.text)
        #print(title)
        print('------------------')
        
        
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")

#print(headlines[0])
# Out:
# 10
# ...
